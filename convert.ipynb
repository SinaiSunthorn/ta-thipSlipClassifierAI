# %%
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("SlipImageClassified/model/bestYOLOslipClassified1.pt")

# Export to TensorFlow Lite (via ONNX → TF → TFLite pipeline internally)
model.export(format="tflite")
# Out:
# Ultralytics 8.3.168  Python-3.10.11 torch-2.7.1+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
#
# PyTorch: starting from 'SlipImageClassified\model\bestYOLOslipClassified1.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 2) (2.8 MB)
# requirements: Ultralytics requirement ['tensorflow>=2.0.0'] not found, attempting AutoUpdate...
# WARNING Retry 1/2 failed: Command 'pip install --no-cache-dir "tensorflow>=2.0.0" ' returned non-zero exit status 1.
# WARNING Retry 2/2 failed: Command 'pip install --no-cache-dir "tensorflow>=2.0.0" ' returned non-zero exit status 1.
# WARNING requirements:  Command 'pip install --no-cache-dir "tensorflow>=2.0.0" ' returned non-zero exit status 1.
# ERROR TensorFlow SavedModel: export failure 556.7s: No module named 'tensorflow.python'
# ---------------------------------------------------------------------------
# ...

# %%
import sys
!"{sys.executable}" -m pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.168-py3-none-any.whl (1.0 MB)
# ...
#   Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#   Using cached torch-2.7.1-cp310-cp310-win_amd64.whl (216.1 MB)
# ...
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# ...
#   Using cached matplotlib-3.10.3-cp310-cp310-win_amd64.whl (8.1 MB)
# ...
#   Using cached torchvision-0.22.1-cp310-cp310-win_amd64.whl (1.7 MB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached pandas-2.3.1-cp310-cp310-win_amd64.whl (11.3 MB)
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#   Using cached fonttools-4.59.0-cp310-cp310-win_amd64.whl (2.3 MB)
# ...
